# %% [markdown]
# # Random Forest

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.dummy import DummyClassifier
from mlxtend.evaluate import paired_ttest_5x2cv
from sklearn.tree import export_graphviz
import pandas as pd
import numpy as np

# %%
# Load database
wdf_df = pd.read_csv('V4_WDF_OFFICIAL.csv')
wdf_df.head()
# Out:
#    Unnamed: 0 FIPS_ID   FIRE_NAME  FIRE_YEAR  DISCOVERY_TIME STAT_CAUSE_DESCR  \
# 0           0  025-01     NORRISH       2000           945.0    Miscellaneous
# 1           1  025-02         GUN       2001          1245.0    Miscellaneous
# 2           2  025-03       ONEAL       2001          1600.0         Campfire
# 3           3  025-04  EXPEDITION       2002          1934.0        Lightning
# 4           4  025-05       M L K       2002          1345.0        Lightning
#
#     CONT_DATE  CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS  ...  LONGITUDE  \
# 0   5/31/2000     1800.0       87.4               C  ...  -115.2919
# 1   5/20/2001     1345.0        0.1               A  ...  -116.1486
# 2   7/17/2001     2200.0       18.0               C  ...  -116.0892
# 3  12/28/2002     2000.0        0.1               A  ...  -115.2050
# 4   1/20/2002     1430.0        0.1               A  ...  -115.1186
#
#    FIPS_NAME DISCOVERY_MONTH  DISCOVERY_DAY    AWND  PRCP  TAVG  \
# 0   Imperial               5             30     NaN   0.0  93.5
# 1   Imperial               5             20   4.920   0.0  88.4
# 2   Imperial               7             17  10.405   0.0  91.0
# 3   Imperial              12             28   3.580   0.0  56.4
# 4   Imperial               1             20   6.040   0.0  52.6
#
#    DURING_A_DROUGHT  WATERSHD  POP_BY_COUNTY
# 0               0.0         0         142359
# 1               0.0         0         143295
# 2               0.0         0         143295
# 3               1.0         0         144818
# 4               0.0         0         144818
#
# [5 rows x 21 columns]

# %%
wdf_df.shape
# Out:
# (17245, 21)

# %% [markdown]
# **Step 1**: Add FIRE_SIZE_CLASS to 2016-Sep 2020 data based on FIRE_SIZE. Remove data points that don't have a FIRE_SIZE listed.
#
# Definition of the following columns:
# - FIRE_SIZE = Estimate of acres within the final perimeter of the fire.
# - FIRE_SIZE_CLASS = Code for fire size based on the number of acres within the final fire perimeter expenditures (A=greater than 0 but less than or equal to 0.25 acres, B=0.26-9.9 acres, C=10.0-99.9 acres, D=100-299 acres, E=300 to 999 acres, F=1000 to 4999 acres, and G=5000+ acres).

# %%
# Remove for null values in FIRE_SIZE from the dataframe
wdf_df = wdf_df[wdf_df['FIRE_SIZE'].notnull()]
wdf_df.reset_index(inplace=True, drop=True)
wdf_df.shape
# Out:
# (17234, 21)

# %%
# Check columns that have null vales in FIRE_SIZE_CLASS
# This should be from FIRE_YEAR 2016-Sept 2020
wdf_df[wdf_df['FIRE_SIZE_CLASS'].isnull()]
# Out:
#        Unnamed: 0   FIPS_ID       FIRE_NAME  FIRE_YEAR  DISCOVERY_TIME  \
# 91             91   025-174     Carter Fire       2020             NaN
# 576           584  029-1360      Cedar Fire       2016             NaN
# 577           585  029-1361     Cotton Fire       2016             NaN
# 578           586  029-1362       Deer Fire       2016             NaN
# 579           587  029-1363    Erskine Fire       2016             NaN
# ...           ...       ...             ...        ...             ...
# 17144       17221   111-148      South Fire       2019             NaN
# 17145       17222   111-149      Wendy Fire       2019             NaN
# 17147       17224   111-150  Elizabeth Fire       2020             NaN
# 17148       17225   111-151     Holser Fire       2020             NaN
# 17149       17226   111-152       Lime Fire       2020             NaN
#
#       STAT_CAUSE_DESCR CONT_DATE  CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS  ...  \
# 91                 NaN  4/4/2020        NaN      275.0             NaN  ...
# 576                NaN       NaN        NaN    29322.0             NaN  ...
# 577                NaN       NaN        NaN       61.0             NaN  ...
# 578                NaN       NaN        NaN     1785.0             NaN  ...
# 579                NaN       NaN        NaN    48019.0             NaN  ...
# ...                ...       ...        ...        ...             ...  ...
# 17144              NaN       NaN        NaN      131.0             NaN  ...
# 17145              NaN       NaN        NaN       91.0             NaN  ...
# 17147              NaN       NaN        NaN      289.0             NaN  ...
# 17148              NaN       NaN        NaN     3000.0             NaN  ...
# 17149              NaN       NaN        NaN      803.0             NaN  ...
#
#         LONGITUDE  FIPS_NAME DISCOVERY_MONTH  DISCOVERY_DAY    AWND  PRCP  \
# 91    -115.586500   Imperial               4              4  12.750   0.0
# 576   -118.567800       Kern               8             16   6.825   0.0
# 577   -120.251000       Kern               6             11   9.840   0.0
# 578   -118.722720       Kern               7              1  10.065   0.0
# 579   -118.456280       Kern               6             23   7.605   0.0
# ...           ...        ...             ...            ...     ...   ...
# 17144 -117.461363    Ventura               7             14   5.220   0.0
# 17145 -118.950833    Ventura              10             10  14.425   0.0
# 17147 -119.178080    Ventura               6             10   6.410   0.0
# 17148 -118.758965    Ventura               8             17   5.520   0.0
# 17149 -118.773470    Ventura               6             10   6.410   0.0
#
#             TAVG  DURING_A_DROUGHT  WATERSHD  POP_BY_COUNTY
# 91     70.666667               0.0         0         182333
# 576    81.400000               1.0         0         880856
# 577    72.800000               1.0         1         880856
# 578    84.400000               1.0         1         880856
# 579    81.400000               1.0         1         880856
# ...          ...               ...       ...            ...
# 17144  76.400000               0.0         1         846006
# 17145  57.600000               0.0         0         846006
# 17147  74.166667               0.0         1         851297
# 17148  82.666667               0.0         0         851297
# 17149  74.166667               0.0         0         851297
#
# [427 rows x 21 columns]

# %%
null_test = wdf_df['FIRE_SIZE_CLASS'].isnull()
null_test
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17229    False
# 17230    False
# 17231    False
# 17232    False
# 17233    False
# Name: FIRE_SIZE_CLASS, Length: 17234, dtype: bool

# %%
# Apply FIRE_SIZE_CLASS to 2016-2020 rows
for i in range(len(wdf_df)):
    if null_test[i] == True:
        if wdf_df.FIRE_SIZE[i] > 0 and wdf_df.FIRE_SIZE[i] <= 0.25:
            wdf_df.FIRE_SIZE_CLASS[i] = 'A'
        if wdf_df.FIRE_SIZE[i] >= 0.26 and wdf_df.FIRE_SIZE[i] <= 9.9:
            wdf_df.FIRE_SIZE_CLASS[i] = 'B'
        if wdf_df.FIRE_SIZE[i] >= 10.0 and wdf_df.FIRE_SIZE[i] <= 99.9:
            wdf_df.FIRE_SIZE_CLASS[i] = 'C'
        if wdf_df.FIRE_SIZE[i] >= 100 and wdf_df.FIRE_SIZE[i] <= 299:
            wdf_df.FIRE_SIZE_CLASS[i] = 'D'
        if wdf_df.FIRE_SIZE[i] >= 300 and wdf_df.FIRE_SIZE[i] <= 999:
            wdf_df.FIRE_SIZE_CLASS[i] = 'E'
        if wdf_df.FIRE_SIZE[i] >= 1000 and wdf_df.FIRE_SIZE[i] <= 4999:
            wdf_df.FIRE_SIZE_CLASS[i] = 'F'
        if wdf_df.FIRE_SIZE[i] >= 5000:
            wdf_df.FIRE_SIZE_CLASS[i] = 'G'
# Out:
# <ipython-input-34-b02a991e9b4d>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wdf_df.FIRE_SIZE_CLASS[i] = 'G'
# <ipython-input-34-b02a991e9b4d>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wdf_df.FIRE_SIZE_CLASS[i] = 'C'
# <ipython-input-34-b02a991e9b4d>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wdf_df.FIRE_SIZE_CLASS[i] = 'F'
# <ipython-input-34-b02a991e9b4d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wdf_df.FIRE_SIZE_CLASS[i] = 'D'
# <ipython-input-34-b02a991e9b4d>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wdf_df.FIRE_SIZE_CLASS[i] = 'E'
# <ipython-input-34-b02a991e9b4d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wdf_df.FIRE_SIZE_CLASS[i] = 'B'

# %%
# Check FIRE_SIZE_CLASS was added from 2016-2020
wdf_df[wdf_df['FIRE_SIZE_CLASS'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, FIPS_ID, FIRE_NAME, FIRE_YEAR, DISCOVERY_TIME, STAT_CAUSE_DESCR, CONT_DATE, CONT_TIME, FIRE_SIZE, FIRE_SIZE_CLASS, LATITUDE, LONGITUDE, FIPS_NAME, DISCOVERY_MONTH, DISCOVERY_DAY, AWND, PRCP, TAVG, DURING_A_DROUGHT, WATERSHD, POP_BY_COUNTY]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# **Step 2**: Check null values in the following columns: AWND, PRCP, TAVG, DURING_A_DROUGHT, WATERSHD, POP_BY_COUNTY. Remove rows if there are null values.

# %%
wdf_df.shape
# Out:
# (17234, 21)

# %%
# Check AWND
wdf_df[wdf_df['AWND'].isnull()]
# Out:
#        Unnamed: 0   FIPS_ID        FIRE_NAME  FIRE_YEAR  DISCOVERY_TIME  \
# 0               0    025-01          NORRISH       2000           945.0
# 3494         3527  037-2741  Martindale Fire       2020             NaN
# 3500         3534  037-2748     Woolsey Fire       2018             NaN
# 10913       10953  065-6576       Candy Fire       2020             NaN
# 17012       17084   083-250      Thomas Fire       2017             NaN
#
#       STAT_CAUSE_DESCR  CONT_DATE  CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS  ...  \
# 0        Miscellaneous  5/31/2000     1800.0       87.4               C  ...
# 3494               NaN        NaN        NaN      230.0               D  ...
# 3500               NaN        NaN        NaN    96949.0               G  ...
# 10913              NaN        NaN        NaN      227.0               D  ...
# 17012              NaN        NaN        NaN   281893.0               G  ...
#
#         LONGITUDE                  FIPS_NAME DISCOVERY_MONTH  DISCOVERY_DAY  \
# 0     -115.291900                   Imperial               5             30
# 3494  -118.400000                Los Angeles               9             28
# 3500  -118.701280    Los Angeles and Ventura              11              8
# 10913 -117.374419                  Riverside               9             29
# 17012 -119.091240  Santa Barbara and Ventura              12              4
#
#        AWND  PRCP       TAVG  DURING_A_DROUGHT  WATERSHD  POP_BY_COUNTY
# 0       NaN   0.0  93.500000               0.0         0         142359
# 3494    NaN   0.0  77.285714               0.0         1       10079000
# 3500    NaN   NaN        NaN               1.0         0       10070000
# 10913   NaN   0.0  81.111111               0.0         0        2517830
# 17012   NaN   NaN        NaN               1.0         0          91574
#
# [5 rows x 21 columns]

# %%
# Remove null values from AWND
wdf_df = wdf_df[wdf_df['AWND'].notnull()]
wdf_df.shape
# Out:
# (17229, 21)

# %%
# Check PRCP
wdf_df[wdf_df['PRCP'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, FIPS_ID, FIRE_NAME, FIRE_YEAR, DISCOVERY_TIME, STAT_CAUSE_DESCR, CONT_DATE, CONT_TIME, FIRE_SIZE, FIRE_SIZE_CLASS, LATITUDE, LONGITUDE, FIPS_NAME, DISCOVERY_MONTH, DISCOVERY_DAY, AWND, PRCP, TAVG, DURING_A_DROUGHT, WATERSHD, POP_BY_COUNTY]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Check TAVG
wdf_df[wdf_df['TAVG'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, FIPS_ID, FIRE_NAME, FIRE_YEAR, DISCOVERY_TIME, STAT_CAUSE_DESCR, CONT_DATE, CONT_TIME, FIRE_SIZE, FIRE_SIZE_CLASS, LATITUDE, LONGITUDE, FIPS_NAME, DISCOVERY_MONTH, DISCOVERY_DAY, AWND, PRCP, TAVG, DURING_A_DROUGHT, WATERSHD, POP_BY_COUNTY]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Check DURING_A_DROUGHT
wdf_df[wdf_df['DURING_A_DROUGHT'].isnull()]
# Out:
#        Unnamed: 0  FIPS_ID FIRE_NAME  FIRE_YEAR  DISCOVERY_TIME  \
# 15387       15449  073-367   HAYBARN       2004          1630.0
# 15512       15574  073-480  SUNDEVIL       2005          1300.0
# 15894       15957  073-829   JULIETT       2008          1442.0
#
#         STAT_CAUSE_DESCR CONT_DATE  CONT_TIME  FIRE_SIZE FIRE_SIZE_CLASS  ...  \
# 15387  Missing/Undefined       NaN        NaN      120.0               D  ...
# 15512  Missing/Undefined       NaN        NaN      160.0               D  ...
# 15894  Missing/Undefined       NaN        NaN     4026.0               F  ...
#
#         LONGITUDE  FIPS_NAME DISCOVERY_MONTH  DISCOVERY_DAY      AWND  \
# 15387 -117.315000  San Diego               9             22  6.997143
# 15512 -117.114444  San Diego               9              5  4.570000
# 15894 -117.296111  San Diego              10             13  8.456000
#
#            PRCP       TAVG  DURING_A_DROUGHT  WATERSHD  POP_BY_COUNTY
# 15387  0.000000  71.166667               NaN         0        1254000
# 15512  0.000741  72.764706               NaN         0        1248000
# 15894  0.000000  59.941176               NaN         0        2977000
#
# [3 rows x 21 columns]

# %%
# Remove null values from DURING_A_DROUGHT
wdf_df = wdf_df[wdf_df['DURING_A_DROUGHT'].notnull()]
wdf_df.shape
# Out:
# (17226, 21)

# %%
# Check WATERSHD
wdf_df[wdf_df['WATERSHD'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, FIPS_ID, FIRE_NAME, FIRE_YEAR, DISCOVERY_TIME, STAT_CAUSE_DESCR, CONT_DATE, CONT_TIME, FIRE_SIZE, FIRE_SIZE_CLASS, LATITUDE, LONGITUDE, FIPS_NAME, DISCOVERY_MONTH, DISCOVERY_DAY, AWND, PRCP, TAVG, DURING_A_DROUGHT, WATERSHD, POP_BY_COUNTY]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Check POP_BY_COUNTY
wdf_df[wdf_df['POP_BY_COUNTY'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, FIPS_ID, FIRE_NAME, FIRE_YEAR, DISCOVERY_TIME, STAT_CAUSE_DESCR, CONT_DATE, CONT_TIME, FIRE_SIZE, FIRE_SIZE_CLASS, LATITUDE, LONGITUDE, FIPS_NAME, DISCOVERY_MONTH, DISCOVERY_DAY, AWND, PRCP, TAVG, DURING_A_DROUGHT, WATERSHD, POP_BY_COUNTY]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# **Step 3**: Random Forest Classifier

# %%
# Create x and y Dataframes
X = wdf_df[['AWND', 'PRCP', 'TAVG', 'DURING_A_DROUGHT', 'WATERSHD', 'POP_BY_COUNTY']]
y = wdf_df['FIRE_SIZE_CLASS']

# Create train and test sets
# random_state as 42 is an arbitrary value
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# Create DecisionTreeClassifer class
# Apply max_depth=6 based on the decision tree model
rf = RandomForestClassifier(random_state=0, max_depth=6)

# Train the model on the data
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=6, random_state=0)

# %%
# Measuring model performance
print('Score:', rf.score(X_test, y_test))
# Out:
# Score: 0.627792436235708

# %%
# Cross Validation
scores = cross_val_score(rf, X_train, y_train, cv=5, scoring='accuracy')
print("Accuracy: {} +/- {}%".format(round(scores.mean()*100, 5), round(scores.std()*100, 5)))
# Out:
# Accuracy: 62.34295 +/- 0.01999%

# %% [markdown]
# **Step 4**: Dummy Classifier
# The dummy classifier gives you a measure of “baseline” performance — i.e. the success rate one should expect to achieve even if simply guessing.
#
# **Link**: https://medium.com/@mamonu/what-is-the-scikit-learn-dummy-classifier-95549d9cd44<br>
# **Documentation**: https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html

# %%
# Dummy Classifier
# Create DummyClassifier class
dummy_clf = DummyClassifier(strategy="stratified", random_state=0)

# Train the model on the data
dummy_clf.fit(X, y)

# Train a dummy classifier to make predictions based on the class values
print('Prediction Values:', dummy_clf.predict(X))

# Measuring model performance
print('Score:', dummy_clf.score(X, y))
# Out:
# Prediction Values: ['A' 'B' 'A' ... 'A' 'B' 'A']
# Score: 0.47521188900499245

# %%
# Cross Validation
# Gather the mean and standard deviation of the accuracy
cv_scores = cross_val_score(dummy_clf, X, y, cv=5, scoring='accuracy')
sm_best_tree_cv_score = cv_scores.mean()
sm_best_tree_cv_score_std = cv_scores.std()
print('The best mean cross-validation accuracy {} +/- {}% on training dataset'.format(
      round(sm_best_tree_cv_score*100,5), round(sm_best_tree_cv_score_std*100, 5)))
# Out:
# The best mean cross-validation accuracy 47.81723 +/- 0.47223% on training dataset

# %% [markdown]
# **Step 5**: 5x2cv Paired t Test
#
# The 5x2cv paired t test is a procedure for comparing the performance of two models (classifiers or regressors). For this case we will compare the decision tree model with the dummy classifier.
#
# **Link**: http://rasbt.github.io/mlxtend/user_guide/evaluate/paired_ttest_5x2cv/<br>
# **Documentation**: http://rasbt.github.io/mlxtend/#welcome-to-mlxtends-documentation

# %%
# 5x2cv Paired t Test
t, p = paired_ttest_5x2cv(estimator1=rf, estimator2=dummy_clf, X=X, y=y, random_seed=1)

print('t statistic: %.3f' % t)
print('p value: %.9f' % p)
# Out:
# t statistic: 36.428
# p value: 0.000000293
